# %%
import pandas as pd
import numpy as np
import sklearn

# %%
# Loading file -- in windows it is like this 
my_df = pd.read_csv('data_file1.txt', sep="\t", header=0)

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
# ID       1000 non-null int64
# A1       998 non-null object
# A2       1000 non-null object
# A3       999 non-null object
# A4       1000 non-null int64
# A5       998 non-null float64
# A6       1000 non-null int64
# A7       1000 non-null int64
# A8       997 non-null float64
# A9       1000 non-null int64
# A10      997 non-null float64
# A11      0 non-null float64
# A12      999 non-null object
# A13      1000 non-null object
# A14      3 non-null float64
# A15      3 non-null object
# A16      997 non-null float64
# A17      1000 non-null int64
# A18      998 non-null float64
# A19      1000 non-null int64
# A20      1000 non-null int64
# A21      995 non-null object
# A22      998 non-null object
# A23      999 non-null object
# A24      1000 non-null object
# A25      1000 non-null object
# A26      1000 non-null object
# A27      1000 non-null object
# A28      999 non-null object
# A29      1000 non-null object
# A30      997 non-null object
# Class    900 non-null float64
# dtypes: float64(8), int64(8), object(16)
# memory usage: 250.1+ KB

# %%
# a bird's eye view of the whole data
with pd.option_context('display.max_rows', 1000, 'display.max_columns', 32):
    print(my_df)
# Out:
#        ID   A1  A2   A3  A4   A5  A6  A7    A8  A9      A10  A11  A12 A13  \
# 0       1   V1  V1   V2   1  2.0   1   1  24.0  30   7721.0  NaN    T   F
# 1       2   V1  V2   V1   4  2.0   2   1  30.0  25   5771.0  NaN    T   F
# 2       3   V1  V1   V1   4  3.0   2   2  24.0  34   2825.0  NaN    T   F
# 3       4   V1  V1   V1   2  3.0   1   1  39.0  32  11760.0  NaN    T   F
# 4       5   V2  V2   V1   4  2.0   2   1  14.0  27    802.0  NaN    T   F
# 5       6   V1  V2   V1   4  3.0   2   1  12.0  35    691.0  NaN    T   F
# 6       7   V2  V2   V1   4  4.0   2   1  15.0  38   1308.0  NaN    T   F
# 7       8   V1  V2   V1   1  4.0   1   1   6.0  32   4611.0  NaN    T   F
# 8       9   V2  V2   V1   4  2.0   1   1  24.0  29   2333.0  NaN    T   F
# 9      10   V2  V2   V1   4  4.0   2   1   9.0  27   1082.0  NaN    T   F
# 10     11   V1  V2   V1   2  2.0   1   1  15.0  25   1264.0  NaN    T   F
# 11     12   V1  V1   V1   4  2.0   3   1  15.0  35   2728.0  NaN    T   F
# 12     13   V1  V2   V1   4  4.0   1   2  18.0  43   2899.0  NaN    T   F
# 13     14   V1  V2   V1   4  2.0   1   1  10.0  23   1275.0  NaN    T   F
# 14     15   V1  V2   V1   4  4.0   1   1  48.0  50   6224.0  NaN    T   F
# 15     16  NaN  V1   V1   4  4.0   1   1  45.0  23   1845.0  NaN    T   F
# 16     17   V2  V1   V1   3  4.0   1   1  24.0  20   2718.0  NaN    T   F
# 17     18   V1  V2   V1   4  2.0   1   1  12.0  28    776.0  NaN    T   F
# 18     19   V1  V1   V1   4  4.0   1   2  48.0  38   6681.0  NaN    T   F
# 19     20   V1  V2   V1   4  4.0   1   1  24.0  24   1207.0  NaN    T   F
# 20     21   V2  V2   V1   2  2.0   2   1   6.0  41    250.0  NaN    T   F
# 21     22   V1  V2   V1   4  4.0   1   1  30.0  23   2406.0  NaN    T   F
# 22     23   V3  V1   V1   3  2.0   1   1  24.0  34   2064.0  NaN    T   F
# 23     24   V3  V2   V1   4  2.0   2   1  30.0  28   5234.0  NaN    T   F
# 24     25   V1  V1   V1   4  4.0   2   1  24.0  54    717.0  NaN    T   F
# 25     26   V3  V1   V1   4  2.0   2   1  24.0  37   4712.0  NaN    T   F
# 26     27   V3  V1   V1   4  3.0   1   1  36.0  30   3959.0  NaN    T   F
# 27     28   V3  V1   V1   2  4.0   4   1  36.0  42   8086.0  NaN    T   F
# 28     29   V1  V1   V1   2  1.0   1   1  12.0  25   1484.0  NaN    T   F
# 29     30   V2  V2   V2   3  2.0   1   1  10.0  35   1418.0  NaN    T   F
# 30     31   V1  V2   V1   4  1.0   1   1  12.0  23   1498.0  NaN    T   F
# 31     32   V1  V1   V1   4  4.0   1   2  24.0  30   3349.0  NaN    T   F
# 32     33   V3  V1   V1   3  4.0   1   1  12.0  55   1424.0  NaN    T   F
# 33     34   V2  V2   V1   1  2.0   2   2  11.0  40   3939.0  NaN    T   F
# 34     35   V2  V2   V1   2  4.0   1   1  12.0  23    841.0  NaN    T   F
# 35     36   V1  V1   V1   4  2.0   2   1   9.0  52    936.0  NaN    T   F
# 36     37   V2  V1   V1   4  2.0   2   2  27.0  32   4526.0  NaN    T   F
# 37     38   V1  V1   V1   3  4.0   2   1  20.0  31   6148.0  NaN    T   F
# 38     39   V1  V2   V1   4  4.0   1   1  30.0  47   3017.0  NaN    T   F
# 39     40   V2  V2   V1   4  3.0   1   1   9.0  28    654.0  NaN    T   F
# 40     41   V1  V1   V1   2  2.0   2   1  24.0  27   8648.0  NaN    T   F
# 41     42   V1  V1   V1   4  2.0   1   1  15.0  28   3343.0  NaN    T   F
# 42     43   V1  V2   V1   2  4.0   2   1  45.0  29  11816.0  NaN    T   F
# 43     44   V3  V2   V1   4  2.0   2   2  48.0  46   7629.0  NaN    T   F
# 44     45   V4  V1   V1   1  4.0   1   1   6.0  54    672.0  NaN    T   F
# 45     46   V1  V2   V1   2  3.0   1   1   6.0  26   3518.0  NaN    T   F
# 46     47   V1  V2   V1   3  2.0   1   1   7.0  34   2415.0  NaN    T   F
# 47     48   V2  V1   V1   3  4.0   1   1  24.0  25   1355.0  NaN    T   F
# 48     49   V1  V1   V1   2  2.0   1   1  10.0  37   1225.0  NaN    T   F
# 49     50   V1  V2   V1   4  4.0   2   1  12.0  23    996.0  NaN    T   F
# 50     51   V3  V1   V1   4  4.0   3   1   6.0  36   1872.0  NaN    T   F
# 51     52   V1  V1   V1   3  4.0   2   1  15.0  23   3368.0  NaN    T   F
# 52     53   V1  V1   V1   3  4.0   1   2  12.0  30   2002.0  NaN    T   F
# 53     54   V1  V1   V1   4  2.0   1   2  27.0  36   3915.0  NaN    T   F
# 54     55   V1  V1   V1   1  1.0   1   1  24.0  22   2039.0  NaN    T   F
# 55     56   V1  V1   V1   4  2.0   1   1  24.0  31    929.0  NaN    T   F
# 56     57   V1  V2   V1   4  1.0   1   1  24.0  54   2255.0  NaN    T   F
# 57     58   V2  V2   V1   2  4.0   1   1   6.0  23    660.0  NaN    T   F
# 58     59   V2  V2   V1   4  2.0   2   1  27.0  23   2520.0  NaN    T   F
# 59     60   V2  V1   V1   3  3.0   2   1  24.0  35   4679.0  NaN    T   F
# 60     61   V2  V2   V1   4  4.0   1   2  12.0  41    888.0  NaN    T   F
# 61     62   V3  V1   V1   4  2.0   1   1  36.0  30  11054.0  NaN    T   F
# 62     63   V1  V1   V1   2  4.0   1   1  12.0  36   1542.0  NaN    T   F
# 63     64   V1  V2   V1   2  4.0   1   1  15.0  20   2221.0  NaN    T   F
# 64     65   V1  V2   V1   4  4.0   1   1  42.0  56   4796.0  NaN    T   F
# 65     66   V1  V2   V1   4  3.0   1   1  12.0  26   1424.0  NaN    T   F
# 66     67   V1  V2   V1   3  4.0   1   1   9.0  59   1364.0  NaN    T   F
# 67     68   V3  V1   V1   4  4.0   1   1  21.0  30  12680.0  NaN    T   F
# 68     69   V1  V2   V1   2  4.0   1   2  42.0  45   7882.0  NaN    T   F
# 69     70   V4  V2   V1   4  1.0   1   1  18.0  25   2473.0  NaN    T   F
# 70     71   V1  V2   V1   2  2.0   2   1  18.0  26   2404.0  NaN    T   F
# 71     72   V3  V1   V1   4  1.0   1   1  24.0  29   2679.0  NaN    T   F
# 72     73   V1  V1   V1   4  2.0   1   1  24.0  28   2284.0  NaN    T   F
# 73     74   V2  V1   V1   4  2.0   1   1  18.0  35   1941.0  NaN    T   F
# 74     75   V1  V2   V2   3  2.0   1   1  12.0  35   1592.0  NaN    T   F
# 75     76   V4  V1   V1   2  3.0   3   1  16.0  68   1175.0  NaN    T   F
# 76     77   V1  V1   V1   3  4.0   1   1  12.0  35   3386.0  NaN    T   F
# 77     78   V1  V2   V1   4  4.0   1   1  18.0  21   1049.0  NaN    T   F
# 78     79   V1  V1   V1   2  2.0   2   1  12.0  36   2247.0  NaN    T   F
# 79     80   V1  V1   V1   2  1.0   1   1   9.0  24   2030.0  NaN    T   F
# 80     81   V1  V1   V1   4  4.0   1   1  24.0  60   1940.0  NaN    T   F
# 81     82   V3  V1   V1   3  4.0   2   2   8.0  51   1164.0  NaN    T   F
# 82     83   V3  V1   V1   1  2.0   1   1  42.0  55   9283.0  NaN    T   F
# 83     84   V1  V2   V1   3  2.0   1   1   9.0  25   2136.0  NaN    T   F
# 84     85   V2  V1   V1   2  4.0   1   2  36.0  35   9055.0  NaN    T   F
# 85     86   V3  V1   V1   1  4.0   1   1   6.0  44   3384.0  NaN    T   F
# 86     87   V2  V2   V1   1  1.0   1   1  18.0  45   3049.0  NaN    T   F
# 87     88   V1  V2   V2   3  4.0   2   2   9.0  48   1288.0  NaN    T   F
# 88     89   V3  V1   V1   2  4.0   2   2  24.0  44   6419.0  NaN    T   F
# 89     90   V2  V2   V1   4  1.0   2   1  24.0  43   1516.0  NaN    T   F
# 90     91   V2  V2   V1   1  4.0   2   1  15.0  27   3643.0  NaN    T   F
# 91     92   V1  V1   V1   4  4.0   2   1  12.0  49   1092.0  NaN    T   F
# 92     93   V1  V2   V1   4  4.0   1   1   6.0  35   1198.0  NaN    T   F
# 93     94   V1  V2   V1   1  1.0   2   1  48.0  30   8358.0  NaN    T   F
# 94     95   V1  V1   V1   4  4.0   1   1  12.0  54   1318.0  NaN    T   F
# 95     96   V1  V2   V1   2  4.0   1   1   9.0  22   2301.0  NaN    T   F
# 96     97   V1  V1   V1   1  2.0   2   1  48.0  27  10961.0  NaN    T   F
# 97     98   V3  V1   V1   3  3.0   1   1  24.0  38   7814.0  NaN    T   F
# 98     99   V1  V2   V1   2  2.0   1   1  12.0  27   1657.0  NaN    T   F
# 99    100   V1  V2   V1   2  1.0   1   1  24.0  29   2896.0  NaN    T   F
# 100   101   V2  V1   V1   2  4.0   1   1  36.0  45   3835.0  NaN    T   F
# 101   102   V2  V2   V1   4  1.0   1   1  12.0  21   1289.0  NaN    T   F
# 102   103   V1  V2   V1   1  4.0   2   1  33.0  23   4281.0  NaN    T   F
# 103   104   V2  V2   V1   4  3.0   1   1   9.0  66    790.0  NaN    T   F
# 104   105   V1  V1   V1   4  3.0   1   1  15.0  47   1213.0  NaN    T   F
# 105   106   V1  V1   V1   4  4.0   1   2  18.0  36    884.0  NaN    T   F
# 106   107   V2  V2   V2   3  3.0   1   1   6.0  26    590.0  NaN    T   F
# 107   108   V1  V2   V1   2  2.0   1   1  18.0  24   3190.0  NaN    T   F
# 108   109   V1  V2   V1   2  4.0   1   1   9.0  49   1126.0  NaN    T   F
# 109   110   V1  V1   V1   2  4.0   1   1  10.0  64   1364.0  NaN    T   F
# 110   111   V1  V2   V1   3  4.0   1   1  22.0  40   2675.0  NaN    T   F
# 111   112   V1  V1   V1   2  4.0   2   1  36.0  40   7678.0  NaN    T   F
# 112   113   V3  V1   V1   4  4.0   2   1   9.0  67   1199.0  NaN    T   F
# 113   114   V2  V2   V2   1  3.0   2   2  10.0  48   2241.0  NaN    T   F
# 114   115   V1  V2   V2   1  2.0   1   2   9.0  26   3577.0  NaN    T   F
# 115   116   V3  V1   V1   4  4.0   1   1  36.0  40   1977.0  NaN    T   F
# 116   117   V2  V2   V1   4  4.0   1   2  18.0  26   1113.0  NaN    T   F
# 117   118   V1  V2   V1   2  3.0   2   1  15.0  25    975.0  NaN    T   F
# 118   119   V1  V1   V1   1  4.0   1   1  12.0  49   2331.0  NaN    T   F
# 119   120   V3  V1   V1   4  3.0   1   1   6.0  30   2063.0  NaN    T   F
# 120   121   V1  V1   V1   2  1.0   2   1  48.0  35   8858.0  NaN    T   F
# 121   122   V3  V1   V1   2  3.0   2   1   9.0  34   1501.0  NaN    T   F
# 122   123   V1  V1   V1   2  4.0   1   1  24.0  48   9277.0  NaN    T   F
# 123   124   V1  V1   V1   1  2.0   1   1  48.0  26   9960.0  NaN    T   F
# 124   125   V2  V2   V1   4  2.0   1   1  24.0  32   1282.0  NaN    T   F
# 125   126   V3  V1   V1   4  2.0   1   1  24.0  44  12579.0  NaN    T   F
# 126   127   V3  V1   V1   4  4.0   1   1  21.0  28   2606.0  NaN    T   F
# 127   128   V1  V2   V1   3  4.0   1   1  12.0  44   1804.0  NaN    T   F
# 128   129   V1  V2   V1   4  2.0   1   1  18.0  28   2659.0  NaN    T   F
# 129   130   V1  V2   V1   2  1.0   1   1   6.0  29    683.0  NaN    T   F
# 130   131   V1  V1   V1   4  3.0   1   1  36.0  29   6887.0  NaN    T   F
# 131   132   V1  V1   V1   2  3.0   2   1  24.0  38   3512.0  NaN    T   F
# 132   133   V1  V2   V1   3  3.0   1   1  27.0  21   2570.0  NaN    T   F
# 133   134   V2  V2   V2   3  4.0   2   2  10.0  32   1231.0  NaN    T   F
# 134   135   V2  V2   V1   2  3.0   1   1  12.0  25    685.0  NaN    T   F
# 135   136   V1  V2   V1   2  2.0   1   1  30.0  49   8386.0  NaN    T   F
# 136   137   V3  V2   V1   4  2.0   1   1  30.0  30   2333.0  NaN    T   F
# 137   138   V1  V2   V1   4  2.0   1   1  24.0  35   1381.0  NaN    T   F
# 138   139   V1  V1   V1   4  1.0   1   1  36.0  42   3804.0  NaN    T   F
# 139   140   V1  V1   V1   3  4.0   2   2  28.0  40   7824.0  NaN    T   F
# 140   141   V1  V2   V1   4  4.0   2   1   6.0  52    338.0  NaN    T   F
# 141   142   V2  V2   V1   2  4.0   2   1  12.0  22   1258.0  NaN    T   F
# 142   143   V1  V2   V1   3  4.0   1   1  12.0  23   1297.0  NaN    T   F
# 143   144   V1  V2   V1   3  1.0   1   1  12.0  24   3016.0  NaN    T   F
# 144   145   V2  V2   V2   4  4.0   2   1  12.0  38   2171.0  NaN    T   F
# 145   146   V1  V2   V1   3  1.0   2   1  18.0  27   3850.0  NaN    T   F
# 146   147   V1  V1   V1   4  3.0   2   1  10.0  49   1038.0  NaN    T   F
# 147   148   V1  V2   V1   4  4.0   1   2  15.0  45   1300.0  NaN    T   F
# 148   149   V1  V1   V1   3  4.0   2   1  60.0  63   6836.0  NaN    T   F
# 149   150   V3  V1   V1   4  4.0   1   1  30.0  66   1908.0  NaN    T   F
# 150   151   V1  V2   V1   3  4.0   2   2  24.0  53   4870.0  NaN    T   F
# 151   152   V1  V2   V1   3  2.0   2   1  12.0  29   3499.0  NaN    T   F
# 152   153   V2  V2   V1   2  4.0   2   1  18.0  23   1936.0  NaN    T   F
# 153   154   V1  V2   V1   3  2.0   1   1  12.0  25   1262.0  NaN    T   F
# 154   155   V1  V1   V1   2  4.0   2   1  36.0  23   7127.0  NaN    T   F
# 155   156   V1  V2   V1   3  4.0   1   1  24.0  53   2835.0  NaN    T   F
# 156   157   V3  V1   V1   3  4.0   2   2  20.0  36   7057.0  NaN    T   F
# 157   158   V1  V1   V1   3  2.0   1   1  24.0  22   3092.0  NaN    T   F
# 158   159   V1  V2   V1   1  1.0   2   1  36.0  28   9572.0  NaN    T   F
# 159   160   V1  V1   V1   1  4.0   3   1  18.0  33   3966.0  NaN    T   F
# 160   161   V3  V1   V1   2  2.0   1   2  12.0  20   1107.0  NaN    T   F
# 161   162   V3  V2   V1   4  4.0   2   1  12.0  66   1526.0  NaN    T   F
# 162   163   V1  V2   V1   4  1.0   1   1  24.0  25   5511.0  NaN    T   F
# 163   164   V3  V1   V1   4  1.0   1   1  24.0  36   1278.0  NaN    T   F
# 164   165   V3  V1   V1   1  2.0   2   1  27.0  30   5965.0  NaN    T   F
# 165   166   V2  V2   V2   3  2.0   1   2  10.0  31   1546.0  NaN    T   F
# 166   167   V2  V2   V2   2  4.0   1   2   6.0  40   1361.0  NaN    T   F
# 167   168   V2  V2   V1   2  4.0   3   1  12.0  57   2748.0  NaN    T   F
# 168   169   V1  V2   V1   4  2.0   1   1  12.0  30   2028.0  NaN    T   F
# 169   170   V1  V1   V1   4  3.0   2   1  24.0  35   2346.0  NaN    T   F
# 170   171   V2  V2   V1   1  4.0   1   1   5.0  74   3448.0  NaN    T   F
# 171   172   V1  V2   V1   4  4.0   2   1  30.0  36   2181.0  NaN    T   F
# 172   173   V2  V1   V1   4  4.0   1   1  24.0  23   3234.0  NaN    T   F
# 173   174   V4  V2   V1   1  2.0   1   1  12.0  24   7472.0  NaN    T   F
# 174   175   V1  V2   V1   4  1.0   2   1  18.0  30   1055.0  NaN    T   F
# 175   176   V3  V1   V1   1  4.0   1   1   6.0  68  14896.0  NaN    T   F
# 176   177   V1  V1   V1   4  1.0   2   1  24.0  26   1382.0  NaN    T   F
# 177   178   V2  V2   V1   3  1.0   1   1  12.0  37   1274.0  NaN    T   F
# 178   179   V2  V2   V1   4  4.0   2   1  12.0  61   1255.0  NaN    T   F
# 179   180   V1  V1   V1   4  2.0   2   1  24.0  33   1851.0  NaN    T   F
# 180   181   V1  V2   V1   4  1.0   1   1   9.0  30    918.0  NaN    T   F
# 181   182   V1  V2   V1   4  4.0   1   1  36.0  24   2323.0  NaN    T   F
# 182   183   V3  V1   V1   2  1.0   1   1  24.0  34   2910.0  NaN    T   F
# 183   184   V2  V1   V1   2  2.0   1   1  12.0  44   1881.0  NaN    T   F
# 184   185   V1  V2   V1   3  2.0   2   1  12.0  27   1185.0  NaN    T   F
# 185   186   V1  V2   V1   1  2.0   2   1   6.0  27   1221.0  NaN    T   F
# 186   187   V2  V2   V1   3  1.0   2   1  13.0  28   1797.0  NaN    T   F
# 187   188   V1  V2   V1   1  4.0   1   1  18.0  20   2039.0  NaN    T   F
# 188   189   V1  V2   V1   4  4.0   3   1  12.0  52    717.0  NaN    T   F
# 189   190   V3  V1   V1   2  4.0   2   1  27.0  42   8318.0  NaN    T   F
# 190   191   V1  V1   V1   3  2.0   1   1   8.0  26    907.0  NaN    T   F
# 191   192   V1  V1   V1   2  4.0   1   2   6.0  42   1346.0  NaN    T   F
# 192   193   V1  V1   V1   2  3.0   1   1  21.0  35   3976.0  NaN    T   F
# 193   194   V1  V2   V1   4  2.0   2   1  36.0  27   2613.0  NaN    T   F
# 194   195   V3  V1   V1   2  2.0   1   1  36.0  32   4686.0  NaN    T   F
# 195   196   V1  V2   V1   4  4.0   2   1  24.0  23   1442.0  NaN    T   F
# 196   197   V1  V2   V1   2  1.0   2   1  18.0  25   2238.0  NaN    T   F
# 197   198   V2  V2   V1   2  2.0   1   1  24.0  24   3021.0  NaN    T   F
# 198   199   V3  V1   V1   1  1.0   1   1  21.0  28   2923.0  NaN    T   F
# 199   200   V1  V2   V1   3  2.0   2   1  36.0  37   7409.0  NaN    T   F
# 200   201   V3  V1   V1   2  4.0   1   2  36.0  39      NaN  NaN    T   F
# 201   202   V2  V1   V1   3  4.0   1   2  18.0  35   4380.0  NaN    T   F
# 202   203   V1  V1   V1   3  4.0   2   1  12.0  43   4843.0  NaN    T   F
# 203   204   V1  V2   V1   4  4.0   1   1  12.0  21    902.0  NaN    T   F
# 204   205   V1  V2   V1   4  3.0   2   2  15.0  33    950.0  NaN    T   F
# 205   206   V3  V1   V1   2  4.0   2   2  24.0  46   6842.0  NaN    T   F
# 206   207   V1  V2   V1   3  4.0   1   1  45.0  27   4576.0  NaN    T   F
# 207   208   V1  V1   V1   1  4.0   1   1  15.0  59   5045.0  NaN    T   F
# 208   209   V1  V2   V1   4  1.0   1   1  15.0  23   1444.0  NaN    T   F
# 209   210   V1  V2   V1   2  3.0   3   1  30.0  25   8072.0  NaN    T   F
# 210   211   V1  V2   V1   3  4.0   1   1  48.0  24   4308.0  NaN    T   F
# 211   212   V2  V2   V1   1  4.0   1   2  24.0  43   7393.0  NaN    T   F
# 212   213   V3  V1   V1   2  1.0   1   1  12.0  52   6468.0  NaN    T   F
# 213   214   V1  V2   V1   4  4.0   1   1  39.0  24   2569.0  NaN    T   F
# 214   215   V2  V2   V1   4  4.0   2   1  30.0  26   4280.0  NaN    T   F
# 215   216   V1  V2   V1   2  4.0   2   1  36.0  42  10477.0  NaN    T   F
# 216   217   V3  V1   V1   2  4.0   2   1  24.0  75   6615.0  NaN    T   F
# 217   218   V1  V2   V1   2  2.0   1   2  36.0  26   8229.0  NaN    T   F
# 218   219   V2  V1   V1   1  2.0   1   1   6.0  36   1374.0  NaN    T   F
# 219   220   V1  V2   V1   1  2.0   1   1   6.0  21   1766.0  NaN    T   F
# 220   221   V4  V2   V1   1  2.0   1   1  12.0  38    926.0  NaN    T   F
# 221   222   V1  V1   V1   1  4.0   1   1  36.0  37  12389.0  NaN    T   F
# 222   223   V3  V1   V1   4  4.0   1   1  12.0  53   7865.0  NaN    T   F
# 223   224   V2  V2   V1   1  2.0   1   1   9.0  33   3195.0  NaN    T   F
# 224   225   V2  V2   V1   2  4.0   1   1   9.0  51   2507.0  NaN    T   F
# 225   226   V1  V2   V1   4  1.0   1   1  15.0  46   1845.0  NaN    T   F
# 226   227   V2  V2   V1   3  2.0   1   1  12.0  24   1768.0  NaN    T   F
# 227   228   V2  V2   V1   1  2.0   2   2   6.0  34   1898.0  NaN    T   F
# 228   229   V1  V2   V1   2  1.0   1   1  12.0  22   1331.0  NaN    T   F
# 229   230   V1  V1   V1   4  4.0   4   2  27.0  48   5190.0  NaN    T   F
# 230   231   V1  V2   V1   3  4.0   2   1  24.0  44   5507.0  NaN    T   F
# 231   232   V1  V2   V1   2  2.0   2   1  30.0  32   4583.0  NaN    T   F
# 232   233   V3  V1   V1   4  4.0   4   2  27.0  43   2442.0  NaN    T   F
# 233   234   V3  V2   V1   4  2.0   1   2  24.0  30   1823.0  NaN    T   F
# 234   235   V3  V1   V1   3  2.0   1   1  24.0  26   3235.0  NaN    T   F
# 235   236   V1  V1   V1   3  2.0   1   1  15.0  29   3959.0  NaN    T   F
# 236   237   V2  V2   V1   4  4.0   1   1  12.0  57    709.0  NaN    T   F
# 237   238   V1  V2   V1   1  1.0   2   1   6.0  27   1237.0  NaN    T   F
# 238   239   V4  V2   V2   1  1.0   3   2   6.0  74   1299.0  NaN    T   F
# 239   240   V3  V1   V1   4  2.0   2   1  12.0  42   2292.0  NaN    T   F
# 240   241   V2  V2   V1   1  2.0   2   1   6.0  34   1743.0  NaN    T   F
# 241   242   V1  V2   V1   1  1.0   1   1  12.0  23   1534.0  NaN    T   F
# 242   243   V1  V1   V1   2  1.0   2   1  36.0  24   2145.0  NaN    T   F
# 243   244   V3  V1   V1   4  2.0   1   1  36.0  57  14318.0  NaN    T   F
# 244   245   V1  V2   V1   1  1.0   1   2   4.0  37   3380.0  NaN    T   F
# 245   246   V2  V2   V1   2  3.0   1   2  12.0  38    708.0  NaN    T   F
# 246   247   V4  V1   V1   1  2.0   1   1   6.0  23  14555.0  NaN    T   F
# 247   248   V1  V2   V1   4  2.0   2   1  18.0  24   1800.0  NaN    T   F
# 248   249   V1  V1   V1   2  2.0   2   1  33.0  26   2764.0  NaN    T   F
# 249   250   V1  V1   V1   4  3.0   1   1  21.0  41   3160.0  NaN    T   F
# 250   251   V2  V1   V1   3  3.0   2   1  24.0  27   4139.0  NaN    T   F
# 251   252   V3  V1   V1   3  2.0   2   1  36.0  25   8065.0  NaN    T   F
# 252   253   V1  V1   V1   1  2.0   1   1  11.0  28   2142.0  NaN    T   F
# 253   254   V1  V2   V1   1  2.0   1   1   6.0  56   1538.0  NaN    T   F
# 254   255   V1  V2   V1   1  2.0   1   1  48.0  24   8487.0  NaN    T   F
# 255   256   V1  V1   V1   4  4.0   1   1  30.0  58   1867.0  NaN    T   F
# 256   257   V2  V1   V1   3  4.0   1   2   6.0  41    662.0  NaN    T   F
# 257   258   V1  V1   V1   4  1.0   2   1  18.0  34   1950.0  NaN    T   F
# 258   259   V1  V1   V1   4  3.0   1   1  10.0  40    894.0  NaN    T   F
# 259   260   V2  V2   V1   4  2.0   1   1  12.0  23    836.0  NaN    T   F
# 260   261   V4  V2   V1   4  1.0   1   1  12.0  26    609.0  NaN    T   F
# 261   262   V3  V1   V1   4  4.0   1   1  24.0  29   1901.0  NaN    T   F
# 262   263   V1  V1   V1   2  2.0   1   1   6.0  41   2116.0  NaN    T   F
# 263   264   V2  V2   V2   3  2.0   1   2  10.0  40   1597.0  NaN    T   F
# 264   265   V3  V2   V1   4  2.0   1   1  60.0  24   7408.0  NaN    T   F
# 265   266   V1  V2   V1   3  1.0   2   2  36.0  32   2273.0  NaN    T   F
# 266   267   V1  V1   V1   2  4.0   2   2   6.0  28   1323.0  NaN    T   F
# 267   268   V1  V2   V1   4  4.0   1   1  24.0  32   1285.0  NaN    T   F
# 268   269   V2  V2   V1   3  3.0   1   1  18.0  28   6260.0  NaN    T   F
# 269   270   V2  V2   V1   4  4.0   1   1  10.0  23   1048.0  NaN    T   F
# 270   271   V1  V2   V1   4  2.0   1   1  48.0  30   3566.0  NaN    T   F
# 271   272   V1  V2   V1   3  2.0   1   1  15.0  29   3556.0  NaN    T   F
# 272   273   V1  V2   V1   2  3.0   1   1   6.0  64    753.0  NaN    T   F
# 273   274   V1  V2   V1   4  2.0   2   1  24.0  27   5804.0  NaN    T   F
# 274   275   V3  V1   V1   4  4.0   1   1  24.0  35   2670.0  NaN    T   F
# 275   276   V1  V2   V1   4  1.0   1   1  12.0  22   1858.0  NaN    T   F
# 276   277   V2  V2   V1   4  4.0   2   1   8.0  47    731.0  NaN    T   F
# 277   278   V1  V2   V1   4  3.0   1   1  24.0  32   1938.0  NaN    T   F
# 278   279   V1  V2   V1   4  3.0   1   1  12.0  22    741.0  NaN    T   F
# 279   280   V1  V2   V1   4  3.0   2   2   9.0  32   1136.0  NaN    T   F
# 280   281   V4  V2   V1   3  2.0   1   1  36.0  29   3990.0  NaN    T   F
# 281   282   V1  V2   V1   1  4.0   1   1   9.0  20   1313.0  NaN    T   F
# 282   283   V2  V2   V1   1  4.0   2   1  11.0  39   7228.0  NaN    T   F
# 283   284   V3  V1   V1   4  3.0   1   2  18.0  30   2249.0  NaN    T   F
# 284   285   V1  V2   V1   1  1.0   1   1   7.0  45   2329.0  NaN    T   F
# 285   286   V1  V2   V1   4  3.0   1   1  18.0  27   1924.0  NaN    T   F
# 286   287   V4  V2   V1   4  4.0   2   1  42.0  65   3394.0  NaN    T   F
# 287   288   V1  V1   V1   4  4.0   1   1  12.0  23   1200.0  NaN    T   F
# 288   289   V2  V2   V1   2  4.0   1   1  12.0  61   3059.0  NaN    T   F
# 289   290   V1  V2   V1   2  2.0   2   2  18.0  36   4165.0  NaN    T   F
# 290   291   V1  V2   V1   4  2.0   2   1  18.0  30   1864.0  NaN    T   F
# 291   292   V1  V1   V1   2  4.0   1   1  12.0  49   5801.0  NaN    T   F
# 292   293   V1  V2   V1   2  3.0   1   1   9.0  29   1437.0  NaN    T   F
# 293   294   V1  V2   V1   4  2.0   2   2  24.0  43   1333.0  NaN    T   F
# 294   295   V1  V2   V1   2  4.0   1   1  12.0  20   1282.0  NaN    T   F
# 295   296   V3  V1   V1   2  4.0   2   2  18.0  39   6458.0  NaN    T   F
# 296   297   V1  V1   V1   3  4.0   1   2  24.0  63   2924.0  NaN    T   F
# 297   298   V1  V1   V1   4  2.0   2   1  24.0  33   2058.0  NaN    T   F
# 298   299   V1  V2   V1   4  4.0   2   1  36.0  34   4454.0  NaN    T   F
# 299   300   V1  V2   V1   1  2.0   1   1  24.0  33   6403.0  NaN    T   F
# 300   301   V2  V2   V1   4  4.0   1   2  15.0  34   1569.0  NaN    T   F
# 301   302   V1  V1   V1   2  4.0   1   1  24.0  25   3972.0  NaN    T   F
# 302   303   V2  V2   V1   2  1.0   3   2   4.0  42   1544.0  NaN    T   F
# 303   304   V1  V2   V1   4  2.0   1   1  48.0  38   3914.0  NaN    T   F
# 304   305   V3  V1   V1   4  3.0   2   1  18.0  32    629.0  NaN    T   F
# 305   306   V4  V1   V1   3  4.0   1   1  48.0  40   5381.0  NaN    T   F
# 306   307   V1  V2   V1   4  2.0   2   1  12.0  32    701.0  NaN    T   F
# 307   308   V1  V1   V1   4  4.0   2   1  36.0  27   7980.0  NaN    T   F
# 308   309   V1  V1   V1   1  2.0   2   1  18.0  23   8471.0  NaN    T   F
# 309   310   V2  V2   V1   4  4.0   2   1  30.0  49   3656.0  NaN    T   F
# 310   311   V1  V2   V1   4  3.0   2   1  15.0  33   1478.0  NaN    T   F
# 311   312   V2  V2   V1   4  4.0   2   1   6.0  52    362.0  NaN    T   F
# 312   313   V1  V2   V1   2  3.0   1   1  15.0  36   1721.0  NaN    T   F
# 313   314   V4  V2   V1   4  2.0   1   1   9.0  35   1549.0  NaN    T   F
# 314   315   V1  V2   V1   1  3.0   2   1  10.0  23   2146.0  NaN    T   F
# 315   316   V2  V2   V1   1  2.0   1   1  12.0  46   2251.0  NaN    T   F
# 316   317   V1  V2   V1   4  1.0   1   1  24.0  22   3149.0  NaN    T   F
# 317   318   V3  V1   V1   4  2.0   2   1  12.0  29   1412.0  NaN    T   F
# 318   319   V1  V1   V1   4  4.0   2   1  24.0  63   2957.0  NaN    T   F
# 319   320   V2  V2   V1   4  4.0   1   2  48.0  34   3844.0  NaN    T   F
# 320   321   V1  V2   V1   4  4.0   2   1  12.0  20    585.0  NaN    T   F
# 321   322   V3  V1   V1   4  2.0   2   2  12.0  31   1963.0  NaN    T   F
# 322   323   V1  V1   V1   4  4.0   2   2  12.0  42    522.0  NaN    T   F
# 323   324   V1  V2   V2   2  3.0   2   1  10.0  27   2132.0  NaN    T   F
# 324   325   V1  V1   V1   2  2.0   2   1  36.0  31   5742.0  NaN    T   F
# 325   326   V1  V2   V1   2  3.0   2   1  18.0  34   2320.0  NaN    T   F
# 326   327   V1  V1   V1   4  4.0   2   1  48.0  46   6331.0  NaN    T   F
# 327   328   V2  V2   V1   3  4.0   1   1  12.0  31   1736.0  NaN    T   F
# 328   329   V3  V1   V1   3  2.0   2   1  18.0  35   3780.0  NaN    T   F
# 329   330   V3  V1   V1   3  4.0   3   2  30.0  38  10623.0  NaN    T   F
# 330   331   V1  V1   V1   4  4.0   1   1  24.0  22   2483.0  NaN    T   F
# 331   332   V3  V1   V1   2  4.0   1   1  10.0  70   7308.0  NaN    T   F
# 332   333   V1  V2   V1   3  4.0   2   2  48.0  53   7119.0  NaN    T   F
# 333   334   V1  V1   V1   2  2.0   2   1  18.0  30   5866.0  NaN    T   F
# 334   335   V4  V1   V1   1  2.0   1   1   6.0  23   1352.0  NaN    T   F
# 335   336   V3  V1   V1   4  4.0   1   2   6.0  36   1238.0  NaN    T   F
# 336   337   V2  V2   V1   2  4.0   2   1  48.0  24  11590.0  NaN    T   F
# 337   338   V1  V2   V1   4  4.0   1   1  36.0  36   3079.0  NaN    T   F
# 338   339   V1  V2   V1   2  4.0   1   1  15.0  28   1403.0  NaN    T   F
# 339   340   V1  V2   V1   4  3.0   1   1  12.0  54   1409.0  NaN    T   F
# 340   341   V2  V1   V1   4  3.0   1   1  18.0  47   1217.0  NaN    T   F
# 341   342   V3  V1   V1   2  4.0   3   1  18.0  36   5302.0  NaN    T   F
# 342   343   V3  V1   V1   4  2.0   1   1  36.0  28   3349.0  NaN    T   F
# 343   344   V2  V2   V1   2  3.0   2   2  12.0  47    958.0  NaN    T   F
# 344   345   V1  V1   V1   4  4.0   2   1  36.0  57   2225.0  NaN    T   F
# 345   346   V2  V2   V1   2  2.0   1   1  24.0  21   6568.0  NaN    T   F
# 346   347   V1  V1   V1   4  4.0   2   1  24.0  60   2032.0  NaN    T   F
# 347   348   V1  V2   V1   2  4.0   1   1   6.0  50   1236.0  NaN    T   F
# 348   349   V1  V2   V1   3  3.0   2   1  12.0  60   2246.0  NaN    T   F
# 349   350   V1  V1   V1   4  2.0   1   2  30.0  34   3496.0  NaN    T   F
# 350   351   V1  V2   V1   4  2.0   1   1  24.0  25   5152.0  NaN    T   F
# 351   352   V2  V2   V1   4  4.0   1   1  10.0  27   1309.0  NaN    T   F
# 352   353   V1  V1   V1   4  2.0   2   1  12.0  28   6199.0  NaN    T   F
# 353   354   V2  V2   V1   4  4.0   2   1   9.0  25   1138.0  NaN    T   F
# 354   355   V1  V1   V1   2  2.0   2   2  36.0  45  10875.0  NaN    T   F
# 355   356   V3  V1   V1   4  1.0   2   1  18.0  32   1880.0  NaN    T   F
# 356   357   V1  V1   V1   2  4.0   1   1  18.0  67   3872.0  NaN    T   F
# 357   358   V1  V2   V1   3  4.0   2   1  27.0  26   5117.0  NaN    T   F
# 358   359   V1  V2   V1   4  1.0   1   1  18.0  33   2051.0  NaN    T   F
# 359   360   V1  V1   V1   4  4.0   2   1  36.0  37   3535.0  NaN    T   F
# 360   361   V2  V2   V1   1  2.0   2   1  15.0  46   3594.0  NaN    T   F
# 361   362   V1  V2   V1   2  4.0   1   1  48.0  37   7685.0  NaN    T   F
# 362   363   V2  V2   V1   4  2.0   1   1  10.0  31   1521.0  NaN    T   F
# 363   364   V1  V2   V1   4  4.0   1   1  24.0  28   4169.0  NaN    T   F
# 364   365   V1  V2   V1   4  4.0   1   1  45.0  21   3031.0  NaN    T   F
# 365   366   V1  V2   V1   4  4.0   1   1  24.0  55   1603.0  NaN    T   F
# 366   367   V1  V2   V1   1  3.0   1   2  12.0  31   3651.0  NaN    T   F
# 367   368   V1  V1   V1   4  4.0   2   1  10.0  63    781.0  NaN    T   F
# 368   369   V1  V1   V1   2  3.0   1   1  24.0  31   4817.0  NaN    T   F
# 369   370   V1  V1   V1   3  4.0   1   1  18.0  39   1473.0  NaN    T   F
# 370   371   V2  V2   V1   3  2.0   1   1  15.0  25   2631.0  NaN    T   F
# 371   372   V1  V2   V1   3  2.0   1   1  30.0  38   5954.0  NaN    T   F
# 372   373   V1  V1   V1   3  2.0   2   2  42.0  26   4370.0  NaN    T   F
# 373   374   V2  V2   V1   1  4.0   1   1   9.0  64   3832.0  NaN    T   F
# 374   375   V1  V1   V1   4  1.0   1   1  24.0  25   1258.0  NaN    T   F
# 375   376   V3  V1   V1   4  3.0   1   1  18.0  40   4297.0  NaN    T   F
# 376   377   V1  V1   V1   3  4.0   2   1  18.0  33   6070.0  NaN    T   F
# 377   378   V4  V1   V1   3  3.0   3   2  18.0  40   3590.0  NaN    T   F
# 378   379   V1  V1   V1   3  2.0   2   1  21.0  32   2745.0  NaN    T   F
# 379   380   V1  V2   V1   4  4.0   1   1  12.0  38    804.0  NaN    T   F
# 380   381   V2  V2   V1   4  4.0   2   2  18.0  32   1442.0  NaN    T   F
# 381   382   V1  V2   V1   4  4.0   1   1  36.0  39   2299.0  NaN    T   F
# 382   383   V1  V2   V1   1  1.0   1   1  48.0  27   3609.0  NaN    T   F
# 383   384   V3  V1   V1   2  4.0   1   1  18.0  38   3229.0  NaN    T   F
# 384   385   V2  V2   V1   4  1.0   1   1  12.0  45    339.0  NaN    T   F
# 385   386   V1  V1   V1   4  4.0   1   1  15.0  23    392.0  NaN    T   F
# 386   387   V2  V2   V1   2  1.0   3   2   4.0  42   1455.0  NaN    T   F
# 387   388   V1  V2   V1   1  2.0   1   2   9.0  32   2697.0  NaN    T   F
# 388   389   V1  V1   V1   4  3.0   2   2  48.0  38   2751.0  NaN    T   F
# 389   390   V1  V1   V1   4  4.0   2   1  15.0  46   1829.0  NaN    T   F
# 390   391   V3  V1   V1   4  1.0   1   1  36.0  30   4795.0  NaN    T   F
# 391   392   V2  V1   V1   3  4.0   2   1  18.0  48   1795.0  NaN    T   F
# 392   393   V2  V1   V1   1  3.0   2   2  36.0  31   9857.0  NaN    T   F
# 393   394   V1  V1   V1   4  3.0   2   1  12.0  51    682.0  NaN    T   F
# 394   395   V1  V2   V1   4  3.0   2   1  12.0  28   1108.0  NaN    T   F
# 395   396   V1  V2   V1   2  2.0   2   2   9.0  36   2799.0  NaN    T   F
# 396   397   V3  V1   V1   4  1.0   1   1  36.0  29   9034.0  NaN    T   F
# 397   398   V2  V1   V1   1  1.0   1   1  47.0  35  10722.0  NaN    T   F
# 398   399   V1  V1   V1   1  2.0   1   1   6.0  32   2978.0  NaN    T   F
# 399   400   V2  V2   V1   3  2.0   1   1   9.0  28    745.0  NaN    T   F
# 400   401   V1  V2   V1   3  4.0   1   1  24.0  51   2892.0  NaN    T   F
# 401   402   V2  V2   V1   4  2.0   1   1  24.0  23   1246.0  NaN    T   F
# 402   403   V2  V2   V1   1  1.0   1   1  12.0  23   3573.0  NaN    T   F
# 403   404   V1  V2   V1   2  4.0   1   1  24.0  26   2812.0  NaN    T   F
# 404   405   V1  V1   V1   4  2.0   3   1  12.0  28    939.0  NaN    T   F
# 405   406   V1  V2   V1   2  4.0   1   1  13.0  64   1409.0  NaN    T   F
# 406   407   V3  V1   V1   3  4.0   1   2  24.0  41   6313.0  NaN    T   F
# 407   408   V3  V1   V1   4  2.0   1   1  24.0  29   6579.0  NaN    T   F
# 408   409   V2  V2   V1   2  2.0   1   2   9.0  37   2118.0  NaN    T   F
# 409   410   V1  V2   V2   4  2.0   1   1  15.0  27   1053.0  NaN    T   F
# 410   411   V1  V1   V2   1  4.0   1   1  10.0  38   1924.0  NaN    T   F
# 411   412   V1  V2   V1   1  4.0   2   1  20.0  24   4272.0  NaN    T   F
# 412   413   V1  V1   V1   4  4.0   1   1  24.0  35   2439.0  NaN    T   F
# 413   414   V3  V1   V1   2  4.0   1   1  60.0  42  10366.0  NaN    T   F
# 414   415   V1  V1   V1   1  4.0   1   1   9.0  23   1236.0  NaN    T   F
# 415   416   V1  V2   V1   4  4.0   2   1  18.0  28   1887.0  NaN    T   F
# 416   417   V1  V1   V1   4  4.0   3   1  12.0  43   1935.0  NaN    T   F
# 417   418   V1  V1   V1   4  3.0   2   1  18.0  29   1169.0  NaN    T   F
# 418   419   V3  V2   V1   1  2.0   1   1  21.0  31   2782.0  NaN    T   F
# 419   420   V2  V2   V1   4  1.0   1   2  12.0  33   2579.0  NaN    T   F
# 420   421   V3  V1   V1   3  2.0   1   1  24.0  74   4526.0  NaN    T   F
# 421   422   V1  V2   V1   4  3.0   1   1  15.0  31   1532.0  NaN    T   F
# 422   423   V1  V1   V1   4  4.0   2   1  24.0  37   1287.0  NaN    T   F
# 423   424   V1  V1   V1   4  3.0   1   1  24.0  26   1311.0  NaN    T   F
# 424   425   V1  V2   V1   4  4.0   2   1  11.0  40   1322.0  NaN    T   F
# 425   426   V3  V1   V1   4  4.0   1   1  48.0  36  12169.0  NaN    T   F
# 426   427   V1  V2   V1   2  3.0   1   1  12.0  30   1620.0  NaN    T   F
# 427   428   V3  V1   V1   4  4.0   2   1  39.0  30  14179.0  NaN    T   F
# 428   429   V2  V2   V1   4  4.0   1   1   9.0  22    276.0  NaN    T   F
# 429   430   V1  V1   V1   4  4.0   2   1   6.0  67   1169.0  NaN    T   F
# 430   431   V1  V2   V1   2  2.0   1   1   7.0  35   2576.0  NaN    T   F
# 431   432   V1  V2   V1   4  4.0   1   1  22.0  25   1283.0  NaN    T   F
# 432   433   V2  V2   V1   2  3.0   1   2  12.0  49   2096.0  NaN    T   F
# 433   434   V1  V2   V2   4  3.0   2   1   6.0  37    609.0  NaN    T   F
# 434   435   V1  V2   V1   2  1.0   1   1  21.0  33   2319.0  NaN    T   F
# 435   436   V3  V1   V1   2  3.0   3   1  24.0  54   4591.0  NaN    T   F
# 436   437   V1  V1   V1   4  4.0   1   1  24.0  33   5150.0  NaN    T   F
# 437   438   V1  V2   V1   4  2.0   1   1  30.0  24   2150.0  NaN    T   F
# 438   439   V1  V2   V1   2  2.0   1   1  36.0  27   3711.0  NaN    T   F
# 439   440   V1  V1   V1   4  3.0   1   2  24.0  34   1525.0  NaN    T   F
# 440   441   V1  V2   V1   4  3.0   1   1  42.0  34   3965.0  NaN    T   F
# 441   442   V1  V1   V1   4  4.0   1   1  24.0  22   2828.0  NaN    T   F
# 442   443   V1  V2   V1   4  2.0   1   1  12.0  28   2073.0  NaN    T   F
# 443   444   V1  V2   V1   2  3.0   1   2   6.0  44   2647.0  NaN    T   F
# 444   445   V1  V1   V1   1  3.0   1   1  18.0  21   2779.0  NaN    T   F
# 445   446   V1  V2   V1   4  2.0   1   1  18.0  33   1042.0  NaN    T   F
# 446   447   V1  V2   V1   4  2.0   1   1  12.0  50   1574.0  NaN    T   F
# 447   448   V1  V2   V1   4  4.0   1   1  36.0  25   2394.0  NaN    T   F
# 448   449   V2  V1   V1   1  4.0   1   1  24.0  48   4351.0  NaN    T   F
# 449   450   V1  V1   V1   4  4.0   1   1  12.0  37   2279.0  NaN    T   F
# 450   451   V1  V2   V1   4  4.0   2   1  18.0  46   1582.0  NaN    T   F
# 451   452   V1  V1   V1   4  4.0   1   1  36.0  37   1819.0  NaN    T   F
# 452   453   V3  V2   V1   1  4.0   2   1  24.0  23  11560.0  NaN    T   F
# 453   454   V2  V2   V1   4  3.0   1   2  12.0  35   3447.0  NaN    T   F
# 454   455   V1  V2   V1   2  2.0   2   1  12.0  26   1934.0  NaN    T   F
# 455   456   V1  V1   V1   3  4.0   2   1  36.0  34   5800.0  NaN    T   F
# 456   457   V1  V1   V1   2  1.0   1   1  18.0  41   6361.0  NaN    T   F
# 457   458   V1  V2   V1   4  4.0   1   1   6.0  23    448.0  NaN    T   F
# 458   459   V1  V1   V1   4  3.0   1   1  18.0  23   1216.0  NaN    T   F
# 459   460   V3  V1   V1   4  4.0   1   1  30.0  26   4530.0  NaN    T   F
# 460   461   V1  V2   V1   4  4.0   1   1  12.0  41   1503.0  NaN    T   F
# 461   462   V1  V2   V1   3  3.0   2   1  18.0  30   1056.0  NaN    T   F
# 462   463   V1  V2   V1   2  4.0   1   1  24.0  26   3749.0  NaN    T   F
# 463   464   V1  V1   V1   4  4.0   1   2  24.0  49   2964.0  NaN    T   F
# 464   465   V1  V1   V1   4  3.0   2   1  24.0  27   2463.0  NaN    T   F
# 465   466   V1  V2   V1   2  2.0   1   1  15.0  33   3029.0  NaN    T   F
# 466   467   V1  V2   V1   2  4.0   1   1  15.0  27   2326.0  NaN    T   F
# 467   468   V2  V2   V2   1  4.0   2   1   8.0  39   3398.0  NaN    T   F
# 468   469   V1  V1   V1   4  2.0   1   1  18.0  21   1126.0  NaN    T   F
# 469   470   V1  V1   V1   4  4.0   1   1  24.0  62   3757.0  NaN    T   F
# 470   471   V1  V2   V1   3  1.0   1   1  12.0  25   1295.0  NaN    T   F
# 471   472   V1  V2   V1   4  4.0   2   1  18.0  24   2124.0  NaN    T   F
# 472   473   V1  V2   V1   1  4.0   1   1  18.0  26   3114.0  NaN    T   F
# 473   474   V1  V2   V1   4  2.0   1   1   9.0  22   1478.0  NaN    T   F
# 474   475   V2  V2   V1   4  4.0   1   1  24.0  41   1469.0  NaN    T   F
# 475   476   V1  V2   V1   4  4.0   2   1  18.0  47   1984.0  NaN    T   F
# 476   477   V3  V1   V1   2  2.0   1   1  18.0  30   1820.0  NaN    T   F
# 477   478   V1  V1   V1   4  2.0   2   1  10.0  27   1347.0  NaN    T   F
# 478   479   V1  V2   V1   4  1.0   1   1  15.0  24    874.0  NaN    T   F
# 479   480   V3  V2   V1   4  4.0   1   1  48.0  42   7763.0  NaN    T   F
# 480   481   V2  V2   V1   4  4.0   2   1  24.0  60   1199.0  NaN    T   F
# 481   482   V1  V2   V1   4  4.0   1   1  12.0  53    795.0  NaN    T   F
# 482   483   V3  V2   V1   2  3.0   1   1   9.0  31   2406.0  NaN    T   F
# 483   484   V1  V1   V1   3  4.0   2   1  24.0  43   4042.0  NaN    T   F
# 484   485   V1  V2   V1   4  4.0   1   1  18.0  61   1239.0  NaN    T   F
# 485   486   V2  V2   V1   2  2.0   2   1  15.0  47   1316.0  NaN    T   F
# 486   487   V1  V2   V1   1  3.0   3   2   6.0  37   3676.0  NaN    T   F
# 487   488   V1  V1   V1   4  3.0   1   1  40.0  27   5998.0  NaN    T   F
# 488   489   V1  V2   V2   3  2.0   1   1  12.0  55   1413.0  NaN    T   F
# 489   490   V1  V2   V1   4  4.0   1   2   6.0  28   1068.0  NaN    T   F
# 490   491   V1  V2   V1   1  4.0   1   1   6.0  31   1957.0  NaN    T   F
# 491   492   V1  V2   V1   3  2.0   1   2   6.0  51   1595.0  NaN    T   F
# 492   493   V1  V1   V1   4  2.0   2   2  24.0  44   2375.0  NaN    T   F
# 493   494   V1  V2   V1   4  1.0   1   1  12.0  29   2149.0  NaN    T   F
# 494   495   V1  V1   V1   4  3.0   1   1   9.0  35   1919.0  NaN    T   F
# 495   496   V1  V1   V1   4  4.0   1   1  24.0  37   2022.0  NaN    T   F
# 496   497   V2  V2   V1   4  4.0   1   1  21.0  36   1572.0  NaN    T   F
# 497   498   V3  V1   V1   3  4.0   1   1  18.0  38  12976.0  NaN    T   F
# 498   499   V1  V2   V1   3  4.0   2   2  48.0  24   4605.0  NaN    T   F
# 499   500   V1  V2   V1   4  4.0   2   1  24.0  52   2223.0  NaN    T   F
# 500   501   V1  V1   V1   4  2.0   1   1  15.0  40   1386.0  NaN    T   F
# 501   502   V3  V1   V1   4  2.0   2   1  12.0  34   1860.0  NaN    T   F
# 502   503   V3  V1   V1   4  2.0   1   1  39.0  45   8588.0  NaN    T   F
# 503   504   V1  V2   V1   2  3.0   1   1  15.0  20   3186.0  NaN    T   F
# 504   505   V1  V1   V1   4  1.0   1   1  12.0  26    763.0  NaN    T   F
# 505   506   V1  V2   V1   4  1.0   1   1  18.0  27   2389.0  NaN    T   F
# 506   507   V2  V2   V2   2  2.0   1   1  21.0  24   3763.0  NaN    T   F
# 507   508   V2  V2   V2   4  2.0   1   1  10.0  45   1287.0  NaN    T   F
# 508   509   V3  V2   V1   3  2.0   1   1  18.0  23   1961.0  NaN    T   F
# 509   510   V1  V2   V1   4  3.0   2   1  24.0  46   2611.0  NaN    T   F
# 510   511   V1  V2   V1   2  1.0   1   1  12.0  42   2577.0  NaN    T   F
# 511   512   V1  V2   V1   1  4.0   1   1  12.0  20   4675.0  NaN    T   F
# 512   513   V2  V2   V1   4  2.0   1   1  12.0  40    701.0  NaN    T   F
# 513   514   V3  V1   V1   4  2.0   2   1  24.0  41   3868.0  NaN    T   F
# 514   515   V1  V2   V1   2  3.0   1   1  12.0  36   1372.0  NaN    T   F
# 515   516   V1  V2   V1   2  3.0   2   1  30.0  36   6742.0  NaN    T   F
# 516   517   V1  V1   V1   1  1.0   2   1  48.0  34   6999.0  NaN    T   F
# 517   518   V1  V1   V1   4  4.0   2   1  15.0  50   1537.0  NaN    T   F
# 518   519   V1  V1   V1   3  2.0   2   1  36.0  46   2348.0  NaN    T   F
# 519   520   V1  V2   V1   4  3.0   2   1  15.0  25   1433.0  NaN    T   F
# 520   521   V2  V2   V1   4  4.0   3   1  11.0  57   1154.0  NaN    T   F
# 521   522   V1  V2   V1   4  2.0   1   1  12.0  23    900.0  NaN    T   F
# 522   523   V1  V2   V1   4  2.0   1   1  12.0  21    886.0  NaN    T   F
# 523   524   V1  V2   V1   4  4.0   1   1  36.0  50   2671.0  NaN    T   F
# 524   525   V2  V2   V1   2  1.0   2   2   4.0  42   1503.0  NaN    T   F
# 525   526   V1  V2   V1   4  3.0   1   1  18.0  44   1553.0  NaN    T   F
# 526   527   V4  V2   V1   2  4.0   3   1  12.0  66   1480.0  NaN    T   F
# 527   528   V1  V2   V1   4  4.0   1   1  60.0  42   6288.0  NaN    T   F
# 528   529   V1  V1   V1   4  2.0   2   1  12.0  46    697.0  NaN    T   F
# 529   530   V1  V1   V1   4  4.0   1   1  10.0  46    727.0  NaN    T   F
# 530   531   V1  V1   V1   2  4.0   1   1  60.0  21  10144.0  NaN    T   F
# 531   532   V1  V2   V1   4  4.0   2   1   6.0  36    700.0  NaN    T   F
# 532   533   V1  V1   V1   1  4.0   2   1   6.0  39    860.0  NaN    T   F
# 533   534   V1  V2   V1   3  4.0   1   1  18.0  22    433.0  NaN    T   F
# 534   535   V1  V2   V1   4  1.0   1   1  12.0  26   1330.0  NaN    T   F
# 535   536   V1  V1   V1   1  2.0   2   1   6.0  24   1554.0  NaN    T   F
# 536   537   V1  V1   V1   4  1.0   1   2  27.0  32   2528.0  NaN    T   F
# 537   538   V1  V1   V1   4  4.0   3   2  12.0  47   1393.0  NaN    T   F
# 538   539   V1  V2   V1   3  4.0   1   1  24.0  23   3488.0  NaN    T   F
# 539   540   V1  V2   V1   4  4.0   2   1  12.0  35    976.0  NaN    T   F
# 540   541   V4  V2   V1   4  4.0   2   1  18.0  65   1098.0  NaN    T   F
# 541   542   V2  V2   V1   4  2.0   1   2  21.0  41   2580.0  NaN    T   F
# 542   543   V1  V1   V1   4  4.0   1   1  21.0  23   2288.0  NaN    T   F
# 543   544   V1  V1   V1   4  3.0   1   1  24.0  38   1533.0  NaN    T   F
# 544   545   V1  V2   V1   2  2.0   1   1  12.0  26   1386.0  NaN    T   F
# 545   546   V1  V2   V1   4  4.0   1   1   6.0  38    368.0  NaN    T   F
# 546   547   V1  V1   V1   1  1.0   2   1  24.0  44   5943.0  NaN    T   F
# 547   548   V3  V1   V1   4  3.0   1   1   6.0  75   1374.0  NaN    T   F
# 548   549   V2  V2   V1   4  2.0   2   1  24.0  35   2684.0  NaN    T   F
# 549   550   V1  V2   V2   1  4.0   2   2   6.0  46   1343.0  NaN    T   F
# 550   551   V1  V2   V1   2  2.0   1   1  24.0  26   1925.0  NaN    T   F
# 551   552   V1  V2   V1   4  1.0   1   1  12.0  20    674.0  NaN    T   F
# 552   553   V1  V2   V1   2  4.0   1   1  24.0  28   3660.0  NaN    T   F
# 553   554   V1  V1   V1   2  2.0   1   1  48.0  23  15672.0  NaN    T   F
# 554   555   V1  V2   V1   3  1.0   1   1  12.0  35   2141.0  NaN    T   F
# 555   556   V1  V1   V1   2  4.0   1   1  16.0  43   2625.0  NaN    T   F
# 556   557   V1  V1   V1   4  3.0   1   1  12.0  50   2390.0  NaN    T   F
# 557   558   V1  V2   V1   2  2.0   1   1  48.0  44  10127.0  NaN    T   F
# 558   559   V1  V2   V1   3  3.0   2   2  48.0  32   7238.0  NaN    T   F
# 559   560   V3  V1   V1   4  3.0   1   1  42.0  30   7174.0  NaN    T   F
# 560   561   V3  V1   V1   3  2.0   1   1   9.0  27   1422.0  NaN    T   F
# 561   562   V1  V1   V1   2  4.0   2   1  20.0  44   3485.0  NaN    T   F
# 562   563   V1  V1   V1   3  1.0   1   1  12.0  26   1158.0  NaN    T   F
# 563   564   V1  V2   V1   4  2.0   1   1  12.0  26    759.0  NaN    T   F
# 564   565   V1  V2   V1   4  3.0   2   1  24.0  40   1585.0  NaN    T   F
# 565   566   V1  V2   V1   4  1.0   1   1  11.0  20   1577.0  NaN    T   F
# 566   567   V1  V1   V1   2  4.0   1   1  24.0  42   5084.0  NaN    T   F
# 567   568   V2  V2   V1   3  2.0   2   1  21.0  28   2993.0  NaN    T   F
# 568   569   V1  V2   V1   2  4.0   1   1  12.0  42   3331.0  NaN    T   F
# 569   570   V1  V1   V1   1  3.0   1   1  48.0  31   6110.0  NaN    T   F
# 570   571   V1  V1   V1   4  4.0   1   1  12.0  29   1893.0  NaN    T   F
# 571   572   V1  V1   V1   1  4.0   2   1  21.0  29   5003.0  NaN    T   F
# 572   573   V1  V2   V1   2  1.0   2   1  21.0  26   3414.0  NaN    T   F
# 573   574   V1  V2   V1   4  4.0   4   1  12.0  65    930.0  NaN    T   F
# 574   575   V1  V1   V1   3  4.0   1   2  24.0  36   2872.0  NaN    T   F
# 575   576   V2  V2   V1   4  1.0   1   2  18.0  43   1533.0  NaN    T   F
# 576   577   V1  V2   V1   4  NaN   1   1  18.0  26   1345.0  NaN    T   F
# 577   578   V1  V2   V1   4  1.0   1   1  18.0  25   3509.0  NaN    T   F
# 578   579   V2  V2   V1   1  2.0   1   2   6.0  26    783.0  NaN    T   F
# 579   580   V1  V2  NaN   3  2.0   2   1  36.0  28   5371.0  NaN    T   F
# 580   581   V1  V1   V1   2  4.0   1   1  12.0  52   3077.0  NaN    T   F
# 581   582   V1  V1   V1   3  4.0   1   1  18.0  37   3612.0  NaN    T   F
# 582   583   V2  V2   V1   4  3.0   1   2  12.0  33    797.0  NaN    T   F
# 583   584   V1  V2   V1   4  2.0   1   1  36.0  26   4210.0  NaN    T   F
# 584   585   V1  V1   V1   1  2.0   1   1  12.0  25   2762.0  NaN    T   F
# 585   586   V2  V2   V1   2  3.0   1   1  15.0  25   2327.0  NaN    T   F
# 586   587   V1  V1   V1   4  2.0   1   1  18.0  28   2169.0  NaN    T   F
# 587   588   V1  V1   V1   3  4.0   1   1  18.0  43   2515.0  NaN    T   F
# 588   589   V2  V2   V1   1  1.0   1   2  10.0  37   3949.0  NaN    T   F
# 589   590   V3  V1   V1   2  3.0   1   2  12.0  45   3527.0  NaN    T   F
# 590   591   V1  V2   V1   3  1.0   1   2  24.0  32   1552.0  NaN    T   F
# 591   592   V1  V2   V1   4  4.0   2   2  12.0  55   1555.0  NaN    T   F
# 592   593   V1  V2   V1   4  4.0   2   1  21.0  65    571.0  NaN    T   F
# 593   594   V1  V2   V1   4  4.0   1   1   9.0  25   1206.0  NaN    T   F
# 594   595   V1  V2   V1   1  4.0   1   1  14.0  22   3973.0  NaN    T   F
# 595   596   V3  V2   V1   3  1.0   1   1  12.0  34   3017.0  NaN    T   F
# 596   597   V1  V2   V1   2  4.0   1   1  24.0  29   7758.0  NaN    T   F
# 597   598   V1  V1   V1   4  4.0   1   1  24.0  26   3181.0  NaN    T   F
# 598   599   V1  V1   V1   2  4.0   1   1  12.0  26   2445.0  NaN    T   F
# 599   600   V1  V2   V1   4  1.0   1   1  12.0  27   1995.0  NaN  NaN   F
# 600   601   V1  V1   V1   2  4.0   2   1  27.0  50   5293.0  NaN    T   F
# 601   602   V2  V2   V1   2  4.0   1   1  24.0  25   4736.0  NaN    T   F
# 602   603   V1  V2   V1   4  2.0   1   1  36.0  31   4473.0  NaN    T   F
# 603   604   V2  V2   V1   4  3.0   1   1  12.0  27   1168.0  NaN    T   F
# 604   605   V1  V1   V1   3  1.0   1   1  18.0  31   3104.0  NaN    T   F
# 605   606   V3  V1   V1   3  4.0   1   1  18.0  36   1940.0  NaN    T   F
# 606   607   V2  V2   V1   2  4.0   3   1   9.0  37   1154.0  NaN    T   F
# 607   608   V1  V1   V1   1  4.0   1   2  18.0  51   7511.0  NaN    T   F
# 608   609   V3  V1   V1   4  4.0   2   1  18.0  40   7374.0  NaN    T   F
# 609   610   V3  V1   V1   4  1.0   1   1  48.0  37  12749.0  NaN    T   F
# 610   611   V2  V1   V1   1  1.0   1   1  30.0  34  11998.0  NaN    T   F
# 611   612   V3  V1   V1   2  3.0   2   2  24.0  39  11938.0  NaN    T   F
# 612   613   V2  V2   V1   2  1.0   2   1  42.0  41   5954.0  NaN    T   F
# 613   614   V1  V2   V1   4  2.0   1   2  36.0  42   3446.0  NaN    T   F
# 614   615   V1  V1   V1   4  2.0   1   1  36.0  51   3342.0  NaN    T   F
# 615   616   V2  V2   V1   4  4.0   1   1  12.0  29   1123.0  NaN    T   F
# 616   617   V1  V2   V1   2  2.0   1   1  12.0  29   2171.0  NaN    T   F
# 617   618   V1  V2   V1   4  4.0   2   1  36.0  36   6304.0  NaN    T   F
# 618   619   V1  V2   V1   4  2.0   2   1  24.0  25   3105.0  NaN    T   F
# 619   620   V1  V1   V1   1  1.0   1   1  12.0  22   1567.0  NaN    T   F
# 620   621   V1  V2   V1   2  4.0   1   2  36.0  42   5493.0  NaN    T   F
# 621   622   V2  V2   V1   4  2.0   1   1   8.0  44    760.0  NaN    T   F
# ...
# 543  V2  V1   V4  V3   V1    1.0
# 544  V2  V1   V2  V1   V1    0.0
# 545  V1  V1   V2  V1   V1    1.0
# 546  V2  V1   V4  V1   V1    0.0
# 547  V2  V1   V2  V1   V1    1.0
# 548  V1  V1   V1  V1   V1    1.0
# 549  V1  V1   V1  V1   V1    1.0
# 550  V1  V1   V1  V1   V1    1.0
# 551  V4  V1   V2  V1   V1    0.0
# 552  V2  V1   V4  V1   V1    1.0
# 553  V1  V1   V4  V1   V1    0.0
# 554  V1  V1   V3  V1   V1    1.0
# 555  V1  V2   V2  V2   V3    0.0
# 556  V1  V1   V4  V1   V1    1.0
# 557  V1  V1   V3  V2   V2    0.0
# 558  V1  V1   V4  V2   V1    1.0
# 559  V2  V1   V4  V1   V1    0.0
# 560  V1  V1   V3  V1   V2    0.0
# 561  V3  V1   V1  V1   V1    1.0
# 562  V3  V1   V4  V1   V1    1.0
# 563  V1  V1   V1  V1   V1    0.0
# 564  V1  V1   V2  V1   V1    1.0
# 565  V2  V1   V1  V1   V1    1.0
# 566  V2  V1   V4  V1   V1    1.0
# 567  V1  V1   V1  V3   V1    1.0
# 568  V1  V1   V2  V3   V1    1.0
# 569  V1  V1   V3  V2   V2    1.0
# 570  V2  V2   V2  V1   V1    1.0
# 571  V2  V1   V2  V2   V1    0.0
# 572  V1  V1   V2  V1   V1    0.0
# 573  V1  V1   V1  V1   V1    1.0
# 574  V1  V1   V1  V1   V1    1.0
# 575  V4  V3   V2  V1   V1    0.0
# 576  V4  V1   V1  V2   V1    0.0
# 577  V2  V2   V1  V1   V1    1.0
# 578  V1  V2   V1  V3   V1    1.0
# 579  V1  V2   V2  V1   V1    1.0
# 580  V1  V1   V4  V1   V1    1.0
# 581  V2  V1   V2  V1   V1    1.0
# 582  V2  V1   V2  V2   V1    0.0
# 583  V1  V1   V4  V1   V1    0.0
# 584  V2  V1   V2  V2   V1    0.0
# 585  V2  V1   V1  V1   V1    0.0
# 586  V4  V1   V4  V1   V1    0.0
# 587  V1  V1   V1  V1   V1    1.0
# 588  V1  V2   V2  V1   V1    1.0
# 589  V1  V1   V2  V1   V1    1.0
# 590  V1  V1   V4  V2   V1    1.0
# 591  V1  V1   V3  V1   V2    0.0
# 592  V1  V1   V1  V1   V1    1.0
# 593  V2  V1   V1  V1   V1    1.0
# 594  V1  V1   V3  V1   V2    1.0
# 595  V2  V1   V1  V1   V3    1.0
# 596  V2  V1   V3  V1   V3    1.0
# 597  V2  V1   V2  V1   V1    1.0
# 598  V4  V1   V4  V1   V3    1.0
# 599  V1  V1   V4  V1   V1    1.0
# 600  V1  V1   V2  V3   V1    0.0
# 601  V2  V1   V4  V2   V1    0.0
# 602  V1  V1   V4  V1   V1    1.0
# 603  V4  V1   V1  V1   V1    1.0
# 604  V1  V1   V2  V2   V1    1.0
# 605  V1  V3   V3  V2   V2    1.0
# 606  V1  V1   V1  V1   V1    1.0
# 607  V1  V1   V2  V1   V2    0.0
# 608  V1  V1   V2  V3   V1    1.0
# 609  V1  V1   V4  V1   V1    1.0
# 610  V3  V1   V3  V1   V1    0.0
# 611  V1  V3   V4  V1   V1    0.0
# 612  V2  V1   V1  V2   V1    1.0
# 613  V1  V1   V4  V1   V1    0.0
# 614  V1  V1   V4  V1   V1    1.0
# 615  V2  V1   V4  V1   V3    0.0
# 616  V2  V1   V4  V2   V1    1.0
# 617  V1  V1   V1  V1   V1    1.0
# 618  V1  V1   V4  V1   V1    1.0
# 619  V2  V1   V4  V1   V1    1.0
# 620  V1  V1   V3  V1   V2    1.0
# 621  V2  V2   V1  V1   V1    1.0
# 622  V1  V1   V4  V2   V1    0.0
# 623  V3  V1   V4  V1   V1    0.0
# 624  V1  V2   V2  V1   V1    1.0
# 625  V1  V1   V4  V1   V1    1.0
# 626  V1  V1   V1  V1   V1    1.0
# 627  V1  V1   V2  V1   V1    1.0
# 628  V1  V3   V3  V1   V3    1.0
# 629  V3  V1   V2  V1   V1    0.0
# 630  V1  V1   V2  V2   V1    1.0
# 631  V1  V1   V2  V1   V1    0.0
# 632  V2  V1   V3  V1   V1    1.0
# 633  V1  V1   V2  V3   V1    1.0
# 634  V1  V1   V2  V1   V1    0.0
# 635  V1  V1   V3  V2   V2    1.0
# 636  V1  V1   V4  V1   V3    1.0
# 637  V2  V1   V1  V1   V3    1.0
# 638  V3  V1   V1  V1   V1    1.0
# 639  V2  V1   V1  V1   V1    0.0
# 640  V1  V1   V4  V3   V1    1.0
# 641  V1  V1   V4  V2   V1    0.0
# 642  V1  V1   V4  V1   V1    1.0
# 643  V2  V1   V4  V2   V1    1.0
# 644  V1  V1   V3  V1   V2    0.0
# 645  V2  V1   V4  V1   V1    0.0
# 646  V1  V1   V4  V1   V1    0.0
# 647  V2  V1   V3  V3   V2    0.0
# 648  V1  V1   V2  V1   V1    1.0
# 649  V1  V1   V2  V1   V3    1.0
# 650  V2  V1   V2  V2   V1    0.0
# 651  V2  V1   V1  V1   V1    1.0
# 652  V1  V1   V1  V2   V1    1.0
# 653  V1  V1   V4  V1   V1    1.0
# 654  V1  V1   V4  V2   V3    0.0
# 655  V1  V1   V4  V1   V1    1.0
# 656  V1  V1   V1  V1   V1    1.0
# 657  V4  V1   V4  V1   V1    1.0
# 658  V2  V1   V4  V1   V1    0.0
# 659  V1  V3   V1  V1   V1    1.0
# 660  V1  V1   V4  V2   V1    1.0
# 661  V1  V1   V3  V1   V3    1.0
# 662  V2  V1   V4  V2   V1    0.0
# 663  V1  V1   V4  V1   V1    1.0
# 664  V4  V1   V1  V1   V1    1.0
# 665  V1  V2   V1  V1   V1    1.0
# 666  V1  V1   V4  V1   V1    0.0
# 667  V4  V1   V1  V1   V3    1.0
# 668  V1  V1   V3  V1   V2    1.0
# 669  V2  V1   V3  V1   V2    0.0
# 670  V1  V2   V1  V1   V1    1.0
# 671  V1  V1   V4  V2   V1    0.0
# 672  V1  V1   V4  V1   V1    1.0
# 673  V1  V1   V2  V3   V1    1.0
# 674  V1  V3   V2  V1   V1    1.0
# 675  V1  V1   V4  V1   V1    0.0
# 676  V1  V1   V3  V1   V2    1.0
# 677  V3  V1   V2  V1   V1    1.0
# 678  V4  V1   V2  V1   V1    1.0
# 679  V1  V3   V2  V1   V1    1.0
# 680  V2  V1   V3  V2   V2    0.0
# 681  V2  V1   V2  V1   V1    1.0
# 682  V1  V1   V4  V1   V1    1.0
# 683  V3  V1   V1  V1   V1    1.0
# 684  V2  V1   V2  V1   V3    1.0
# 685  V1  V1   V2  V1   V1    1.0
# 686  V2  V2   V2  V1   V1    1.0
# 687  V1  V1   V2  V1   V1    1.0
# 688  V2  V1   V4  V1   V1    0.0
# 689  V2  V1   V3  V1   V3    0.0
# 690  V1  V1   V3  V2   V3    0.0
# 691  V2  V1   V1  V1   V3    1.0
# 692  V1  V1   V2  V1   V1    0.0
# 693  V2  V1   V4  V1   V1    1.0
# 694  V1  V1   V1  V1   V1    1.0
# 695  V1  V2   V2  V1   V1    1.0
# 696  V2  V1   V1  V1   V3    1.0
# 697  V1  V1   V3  V1   V2    1.0
# 698  V3  V1   V4  V2   V1    1.0
# 699  V1  V1   V3  V1   V2    0.0
# 700  V2  V1   V4  V1   V3    1.0
# 701  V2  V1   V1  V2   V1    0.0
# 702  V3  V3   V4  V1   V1    1.0
# 703  V1  V1   V1  V1   V1    0.0
# 704  V1  V1   V1  V1   V1    1.0
# 705  V2  V1   V2  V1   V3    1.0
# 706  V2  V1   V4  V1   V1    1.0
# 707  V2  V1   V4  V1   V1    1.0
# 708  V2  V1   V4  V1   V3    1.0
# 709  V3  V1   V2  V1   V1    1.0
# 710  V1  V1   V1  V1   V3    0.0
# 711  V1  V1   V4  V1   V1    0.0
# 712  V1  V1   V2  V1   V1    1.0
# 713  V3  V1   V4  V2   V3    0.0
# 714  V1  V1   V1  V1   V1    1.0
# 715  V1  V1   V1  V1   V1    1.0
# 716  V1  V1   V3  V1   V2    1.0
# 717  V3  V1   V2  V1   V1    0.0
# 718  V1  V1   V2  V1   V1    1.0
# 719  V4  V1   V1  V1   V1    1.0
# 720  V1  V1   V4  V2   V1    1.0
# 721  V2  V1   V2  V1   V3    1.0
# 722  V1  V1   V2  V1   V1    0.0
# 723  V2  V1   V1  V2   V3    1.0
# 724  V2  V1   V1  V1   V1    0.0
# 725  V1  V3   V4  V2   V1    0.0
# 726  V1  V1   V4  V1   V1    1.0
# 727  V1  V1   V3  V1   V3    1.0
# 728  V1  V3   V1  V2   V1    1.0
# 729  V1  V1   V1  V1   V1    0.0
# 730  V1  V1   V1  V1   V1    1.0
# 731  V1  V2   V1  V1   V1    1.0
# 732  V2  V1   V1  V1   V1    1.0
# 733  V1  V1   V1  V1   V1    1.0
# 734  V1  V1   V4  V1   V1    1.0
# 735  V1  V1   V4  V1   V1    1.0
# 736  V2  V1   V4  V1   V3    1.0
# 737  V4  V1   V1  V1   V1    1.0
# 738  V1  V1   V4  V1   V1    1.0
# 739  V2  V1   V4  V1   V1    1.0
# 740  V1  V1   V1  V1   V1    1.0
# 741  V2  V1   V1  V1   V1    1.0
# 742  V1  V1   V4  V1   V1    1.0
# 743  V4  V1   V4  V1   V3    0.0
# 744  V1  V1   V4  V2   V1    0.0
# 745  V4  V1   V1  V1   V3    1.0
# 746  V1  V3   V4  V1   V1    0.0
# 747  V1  V1   V3  V3   V1    0.0
# 748  V4  V1   V1  V1   V1    1.0
# 749  V1  V1   V1  V1   V1    0.0
# 750  V2  V1   V2  V1   V1    1.0
# 751  V1  V3   V1  V1   V1    0.0
# 752  V2  V1   V4  V1   V3    0.0
# 753  V1  V1   V4  V1   V1    0.0
# 754  V1  V1   V1  V2   V3    1.0
# 755  V1  V1   V1  V1   V1    1.0
# 756  V1  V1   V4  V1   V3    1.0
# 757  V1  V1   V2  V2   V1    1.0
# 758  V2  V1   V2  V2   V1    1.0
# 759  V2  V1   V4  V1   V3    0.0
# 760  V1  V1   V1  V1   V1    1.0
# 761  V4  V1   V1  V2   V1    1.0
# 762  V2  V1   V3  V1   V2    1.0
# 763  V1  V2   V1  V1   V1    0.0
# 764  V4  V1   V2  V3   V1    0.0
# 765  V1  V1   V1  V1   V1    1.0
# 766  V2  V1   V1  V1   V1    1.0
# 767  V1  V1   V2  V1   V1    1.0
# 768  V1  V1   V2  V1   V1    1.0
# 769  V1  V1   V3  V1   V2    0.0
# 770  V2  V1   V1  V1   V1    1.0
# 771  V1  V1   V4  V1   V1    1.0
# 772  V2  V1   V4  V3   V1    1.0
# 773  V4  V2   V1  V1   V1    1.0
# 774  V2  V1   V1  V1   V1    0.0
# 775  V2  V2   V4  V2   V3    1.0
# 776  V2  V1   V1  V1   V3    1.0
# 777  V1  V1   V2  V1   V1    1.0
# 778  V1  V3   V4  V1   V1    1.0
# 779  V1  V1   V1  V1   V1    1.0
# 780  V1  V1   V3  V2   V1    0.0
# 781  V2  V1   V1  V1   V1    1.0
# 782  V4  V1   V3  V1   V1    0.0
# 783  V2  V1   V2  V1   V1    1.0
# 784  V1  V1   V4  V1   V1    1.0
# 785  V3  V1   V1  V3   V1    0.0
# 786  V1  V1   V2  V1   V1    1.0
# 787  V2  V1   V4  V1   V1    1.0
# 788  V1  V1   V1  V1   V1    1.0
# 789  V2  V3   V4  V2   V1    1.0
# 790  V4  V1   V4  V1   V1    0.0
# 791  V2  V1   V1  V1   V3    1.0
# 792  V2  V1   V2  V2   V1    1.0
# 793  V2  V1   V2  V1   V3    1.0
# 794  V1  V1   V1  V1   V1    1.0
# 795  V2  V1   V4  V1   V1    1.0
# 796  V1  V1   V4  V1   V1    0.0
# 797  V1  V1   V2  V1   V1    1.0
# 798  V4  V1   V1  V1   V1    1.0
# 799  V1  V1   V4  V2   V1    1.0
# 800  V1  V1   V4  V1   V1    1.0
# 801  V2  V1   V2  V1   V1    1.0
# 802  V4  V1   V1  V1   V1    1.0
# 803  V2  V1   V4  V1   V1    1.0
# 804  V4  V1   V4  V1   V1    0.0
# 805  V1  V1   V4  V2   V1    1.0
# 806  V1  V1   V4  V1   V3    0.0
# 807  V4  V1   V4  V1   V1    0.0
# 808  V1  V1   V4  V1   V1    1.0
# 809  V1  V1   V2  V1   V1    0.0
# 810  V2  V1   V2  V1   V1    1.0
# 811  V2  V1   V4  V1   V1    1.0
# 812  V1  V3   V3  V2   V1    1.0
# 813  V1  V1   V2  V1   V1    1.0
# 814  V1  V1   V2  V1   V1    1.0
# 815  V2  V1   V4  V1   V1    1.0
# 816  V4  V2   V1  V2   V1    1.0
# 817  V2  V1   V3  V2   V2    0.0
# 818  V1  V1   V4  V1   V1    1.0
# 819  V2  V3   V4  V1   V3    0.0
# 820  V3  V1   V1  V1   V3    0.0
# 821  V1  V1   V2  V2   V1    1.0
# 822  V2  V1   V3  V1   V3    1.0
# 823  V2  V1   V2  V1   V3    1.0
# 824  V4  V1   V1  V3   V1    0.0
# 825  V2  V1   V4  V1   V1    1.0
# 826  V1  V1   V3  V2   V2    0.0
# 827  V2  V1   V2  V3   V3    1.0
# 828  V3  V1   V2  V1   V1    1.0
# 829  V4  V1   V1  V1   V1    1.0
# 830  V2  V1   V2  V1   V1    1.0
# 831  V1  V1   V4  V1   V1    1.0
# 832  V4  V1   V4  V1   V1    1.0
# 833  V1  V1   V1  V2   V3    0.0
# 834  V2  V1   V1  V1   V1    0.0
# 835  V1  V1   V1  V1   V3    1.0
# 836  V1  V1   V3  V2   V2    1.0
# 837  V1  V1   V4  V1   V1    1.0
# 838  V2  V1   V4  V1   V3    1.0
# 839  V1  V1   V1  V1   V3    1.0
# 840  V1  V1   V4  V3   V1    1.0
# 841  V2  V1   V4  V1   V1    0.0
# 842  V1  V1   V3  V1   V3    0.0
# 843  V1  V1   V2  V1   V1    1.0
# 844  V1  V1   V2  V1   V1    0.0
# 845  V2  V2   V1  V1   V1    1.0
# 846  V1  V1   V2  V1   V1    1.0
# 847  V2  V1   V4  V1   V1    1.0
# 848  V1  V1   V3  V1   V2    0.0
# 849  V1  V1   V3  V1   V3    0.0
# 850  V1  V1   V3  V1   V2    0.0
# 851  V2  V1   V1  V1   V1    1.0
# 852  V3  V1   V1  V1   V1    1.0
# 853  V1  V1   V4  V1   V1    1.0
# 854  V1  V1   V2  V1   V1    1.0
# 855  V1  V1   V2  V1   V1    1.0
# 856  V2  V1   V3  V1   V2    1.0
# 857  V1  V2   V1  V1   V1    1.0
# 858  V1  V1   V4  V1   V1    1.0
# 859  V1  V1   V3  V2   V3    1.0
# 860  V2  V1   V2  V1   V3    1.0
# 861  V1  V1   V1  V1   V1    1.0
# 862  V1  V1   V3  V1   V2    1.0
# 863  V2  V1   V2  V2   V1    1.0
# 864  V3  V1   V4  V1   V1    1.0
# 865  V2  V1   V2  V1   V3    1.0
# 866  V1  V1   V4  V1   V1    1.0
# 867  V4  V1   V1  V1   V1    1.0
# 868  V4  V1   V3  V1   V2    1.0
# 869  V1  V1   V1  V1   V1    1.0
# 870  V1  V1   V2  V1   V3    1.0
# 871  V1  V1   V4  V1   V1    1.0
# 872  V3  V1   V4  V1   V1    1.0
# 873  V2  V1   V3  V1   V2    0.0
# 874  V4  V2   V1  V2   V1    1.0
# 875  V1  V1   V1  V1   V1    1.0
# 876  V1  V1   V4  V1   V3    1.0
# 877  V1  V1   V1  V1   V1    1.0
# 878  V2  V1   V3  V1   V2    1.0
# 879  V2  V1   V1  V1   V1    0.0
# 880  V2  V1   V3  V1   V2    1.0
# 881  V1  V1   V4  V2   V1    0.0
# 882  V1  V1   V1  V1   V1    1.0
# 883  V1  V1   V3  V1   V1    1.0
# 884  V2  V1   V1  V2   V1    0.0
# 885  V2  V1   V4  V1   V1    0.0
# 886  V1  V2   V4  V2   V3    0.0
# 887  V2  V1   V1  V3   V1    0.0
# 888  V1  V1   V4  V1   V1    1.0
# 889  V4  V1   V2  V1   V1    1.0
# 890  V2  V1   V1  V1   V1    1.0
# 891  V1  V1   V4  V1   V1    1.0
# 892  V2  V1   V2  V3   V1    0.0
# 893  V1  V1   V1  V1   V1    1.0
# 894  V1  V1   V2  V1   V1    1.0
# 895  V2  V1   V4  V1   V1    0.0
# 896  V1  V1   V4  V1   V1    1.0
# 897  V1  V1   V3  V1   V2    1.0
# 898  V2  V1   V4  V1   V3    0.0
# 899  V1  V1   V3  V1   V2    1.0
# 900  V1  V1   V3  V1   V1    NaN
# 901  V1  V1   V3  V1   V2    NaN
# 902  V1  V1  NaN  V1   V1    NaN
# 903  V1  V1   V1  V1   V1    NaN
# 904  V1  V1   V4  V1   V1    NaN
# 905  V1  V1   V2  V1   V1    NaN
# 906  V2  V1   V3  V2   V2    NaN
# 907  V2  V1   V3  V1   V2    NaN
# 908  V2  V1   V1  V1   V3    NaN
# 909  V4  V2   V2  V2   V3    NaN
# 910  V2  V1   V4  V2   V3    NaN
# 911  V2  V1   V4  V2   V3    NaN
# 912  V3  V1   V4  V1   V3    NaN
# 913  V4  V1   V1  V2   V1    NaN
# 914  V2  V1   V2  V1   V1    NaN
# 915  V1  V1   V2  V1   V1    NaN
# 916  V2  V1   V4  V1   V3    NaN
# 917  V2  V3   V3  V1   V3    NaN
# 918  V2  V1   V2  V2   V3    NaN
# 919  V3  V1   V1  V1   V1    NaN
# 920  V1  V1   V4  V1   V1    NaN
# 921  V2  V1   V1  V1   V3    NaN
# 922  V4  V1   V4  V1   V1    NaN
# 923  V2  V1   V4  V1   V3    NaN
# 924  V1  V1   V2  V1   V1    NaN
# 925  V1  V1   V4  V1   V3    NaN
# 926  V2  V1   V1  V1   V3    NaN
# 927  V2  V1   V4  V1   V1    NaN
# 928  V1  V1   V3  V3   V2    NaN
# 929  V1  V1   V4  V1   V3    NaN
# 930  V2  V1   V4  V1   V1    NaN
# 931  V4  V1   V2  V1   V1    NaN
# 932  V2  V1   V4  V1   V1    NaN
# 933  V1  V1   V4  V1   V1    NaN
# 934  V1  V1   V2  V1   V1    NaN
# 935  V2  V1   V4  V1   V1    NaN
# 936  V1  V1   V2  V1   V1    NaN
# 937  V4  V2   V1  V1   V1    NaN
# 938  V1  V1   V1  V1   V1    NaN
# 939  V1  V1   V3  V1   V2    NaN
# 940  V1  V1   V3  V1   V1    NaN
# 941  V2  V1   V4  V2   V3    NaN
# 942  V2  V1   V2  V1   V3    NaN
# 943  V1  V1   V2  V2   V1    NaN
# 944  V1  V1   V3  V1   V2    NaN
# 945  V1  V1   V1  V1   V1    NaN
# 946  V4  V1   V2  V1   V3    NaN
# 947  V2  V1   V4  V1   V3    NaN
# 948  V1  V3   V3  V1   V3    NaN
# 949  V1  V1   V2  V1   V1    NaN
# 950  V4  V1   V4  V1   V1    NaN
# 951  V4  V1   V1  V1   V3    NaN
# 952  V1  V3   V1  V3   V1    NaN
# 953  V1  V1   V4  V3   V1    NaN
# 954  V1  V1   V2  V1   V3    NaN
# 955  V2  V1   V1  V1   V1    NaN
# 956  V1  V1   V2  V2   V1    NaN
# 957  V1  V1   V4  V1   V1    NaN
# 958  V1  V1   V2  V2   V1    NaN
# 959  V4  V1   V4  V1   V1    NaN
# 960  V2  V1   V2  V1   V1    NaN
# 961  V2  V1   V1  V1   V1    NaN
# 962  V1  V1   V2  V1   V1    NaN
# 963  V2  V3   V3  V1   V3    NaN
# 964  V1  V1   V3  V1   V2    NaN
# 965  V1  V1   V1  V1   V1    NaN
# 966  V3  V1   V2  V1   V1    NaN
# 967  V1  V1   V1  V1   V1    NaN
# 968  V1  V1   V2  V1  NaN    NaN
# 969  V2  V1   V2  V1   V3    NaN
# 970  V1  V1   V2  V1   V3    NaN
# 971  V1  V1   V4  V3   V1    NaN
# 972  V2  V1   V4  V2   V1    NaN
# 973  V2  V3   V4  V1   V3    NaN
# 974  V1  V1   V1  V2   V1    NaN
# 975  V1  V1   V4  V1   V1    NaN
# 976  V1  V1   V4  V2   V1    NaN
# 977  V3  V1   V1  V1   V1    NaN
# 978  V1  V1   V4  V1   V1    NaN
# 979  V2  V1   V4  V1   V1    NaN
# 980  V1  V1   V1  V1   V1    NaN
# 981  V1  V1   V4  V1   V1    NaN
# 982  V1  V1   V1  V2   V1    NaN
# 983  V1  V1   V2  V1   V1    NaN
# 984  V4  V2   V1  V2   V1    NaN
# 985  V3  V1   V1  V1   V1    NaN
# 986  V2  V1   V2  V1   V3    NaN
# 987  V1  V1   V3  V1   V2    NaN
# 988  V4  V1   V4  V1   V3    NaN
# 989  V3  V1   V2  V1   V1    NaN
# 990  V3  V1   V4  V1   V1    NaN
# 991  V4  V1   V4  V1   V1    NaN
# 992  V3  V1   V2  V2   V1    NaN
# 993  V1  V1   V4  V1   V1    NaN
# 994  V2  V1   V4  V1   V1    NaN
# 995  V1  V2   V1  V1   V1    NaN
# 996  V2  V1   V1  V1   V1    NaN
# 997  V2  V1   V4  V1   V1    NaN
# 998  V1  V1   V4  V1   V1    NaN
# 999  V1  V1   V4  V1   V1    NaN

# %% [markdown]
# # Analyzing the data

# %%
# checking number of 1.0 class examples in the data
index_names = my_df[ my_df['Class'] == 1.0 ].index

# %%
# examples labeled as 1.0
index_names.size
# Out:
# 650

# %%
# checking number of 0.0 lebel class examples in the data
index_names = my_df[ my_df['Class'] == 0.0 ].index

# %%
# examples labeled as 0.0
index_names.size
# Out:
# 250

# %%
# This shows that there is somewhat class imbalance present in th dataset
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
classes = ['1.0 labeled examples', '0.0 labeled examples']
num_example = [650,250]
ax.bar(classes,num_example)
plt.show()

# %%
# checking null columns
null_columns=my_df.columns[my_df.isnull().any()]

# %%
my_df[null_columns].isnull().sum()
# Out:
# A1          2
# A3          1
# A5          2
# A8          3
# A10         3
# A11      1000
# A12         1
# A14       997
# A15       997
# A16         3
# A18         2
# A21         5
# A22         2
# A23         1
# A28         1
# A30         3
# Class     100
# dtype: int64

# %%
# it appears that A11, A14, A15 columns have Null values in almost all places except a few
# it is advisible to remove these columns from the data
# Dropping these columns now
my_df = my_df.drop(['A11'], axis=1)
my_df = my_df.drop(['A14'], axis=1)
my_df = my_df.drop(['A15'], axis=1)

# checking statu of null columns now
null_columns=my_df.columns[my_df.isnull().any()]
my_df[null_columns].isnull().sum()
# Out:
# A1         2
# A3         1
# A5         2
# A8         3
# A10        3
# A12        1
# A16        3
# A18        2
# A21        5
# A22        2
# A23        1
# A28        1
# A30        3
# Class    100
# dtype: int64

# %%
# Columns which do not have any null value
not_null_columns=my_df.columns[my_df.notnull().all()]
my_df[not_null_columns].notnull().sum()
# Out:
# ID     1000
# A2     1000
# A4     1000
# A6     1000
# A7     1000
# A9     1000
# A13    1000
# A17    1000
# A19    1000
# A20    1000
# A24    1000
# A25    1000
# A26    1000
# A27    1000
# A29    1000
# dtype: int64

# %%
# dropping ID column as it has no significance
my_df = my_df.drop(['ID'], axis=1)

# %%
# verifying ID drop
my_df.head(3)
# Out:
#    A1  A2  A3  A4   A5  A6  A7    A8  A9     A10  ... A22 A23  A24  A25  A26  \
# 0  V1  V1  V2   1  2.0   1   1  24.0  30  7721.0  ...  V2  V3   V1   V5   V2
# 1  V1  V2  V1   4  2.0   2   1  30.0  25  5771.0  ...  V1  V1   V2   V3   V2
# 2  V1  V1  V1   4  3.0   2   2  24.0  34  2825.0  ...  V1  V6   V1   V3   V1
#
#    A27  A28 A29 A30 Class
# 0   V1   V2  V1  V1   1.0
# 1   V1   V4  V1  V1   1.0
# 2   V1   V3  V1  V1   1.0
#
# [3 rows x 28 columns]

# %%
# removing those rows which have null values througout the dataframe
my_df = my_df.dropna()
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879 entries, 0 to 899
# Data columns (total 28 columns):
# A1       879 non-null object
# A2       879 non-null object
# A3       879 non-null object
# A4       879 non-null int64
# A5       879 non-null float64
# A6       879 non-null int64
# A7       879 non-null int64
# A8       879 non-null float64
# A9       879 non-null int64
# A10      879 non-null float64
# A12      879 non-null object
# A13      879 non-null object
# A16      879 non-null float64
# A17      879 non-null int64
# A18      879 non-null float64
# A19      879 non-null int64
# A20      879 non-null int64
# A21      879 non-null object
# A22      879 non-null object
# A23      879 non-null object
# A24      879 non-null object
# A25      879 non-null object
# A26      879 non-null object
# A27      879 non-null object
# A28      879 non-null object
# A29      879 non-null object
# A30      879 non-null object
# Class    879 non-null float64
# dtypes: float64(6), int64(7), object(15)
# memory usage: 199.1+ KB

# %%
# # a bird's eye view of the whole data
# with pd.option_context('display.max_rows', 1000, 'display.max_columns', 32):
#     print(my_df)

# %%
# Column A12 and A13 does not have variance so their presence or absence does not count
list_A12 = my_df['A12'].values
print(len(list_A12))
'F' in list_A12
# Out:
# 879
# False

# %%
list_A13 = my_df['A13'].values
print(len(list_A13))
'T' in list_A13
# Out:
# 879
# False

# %%
# Now dropping these columns as well for dimensionality reduction
my_df = my_df.drop(['A12'], axis=1)
my_df = my_df.drop(['A13'], axis=1)

my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879 entries, 0 to 899
# Data columns (total 26 columns):
# A1       879 non-null object
# A2       879 non-null object
# A3       879 non-null object
# A4       879 non-null int64
# A5       879 non-null float64
# A6       879 non-null int64
# A7       879 non-null int64
# A8       879 non-null float64
# A9       879 non-null int64
# A10      879 non-null float64
# A16      879 non-null float64
# A17      879 non-null int64
# A18      879 non-null float64
# A19      879 non-null int64
# A20      879 non-null int64
# A21      879 non-null object
# A22      879 non-null object
# A23      879 non-null object
# A24      879 non-null object
# A25      879 non-null object
# A26      879 non-null object
# A27      879 non-null object
# A28      879 non-null object
# A29      879 non-null object
# A30      879 non-null object
# Class    879 non-null float64
# dtypes: float64(6), int64(7), object(13)
# memory usage: 185.4+ KB

# %% [markdown]
# # String Encoding

# %%
# Columns with string values needed to be encoded
# A1 A2 A3 A21 A22 A23 A24 A25 A26 A27 A28 A29 A30
# In total, 13 columns are needed to be ecoded

# %%
# cheking data types of these aforementiond columns 
my_df.dtypes
# Out:
# A1        object
# A2        object
# A3        object
# A4         int64
# A5       float64
# A6         int64
# A7         int64
# A8       float64
# A9         int64
# A10      float64
# A16      float64
# A17        int64
# A18      float64
# A19        int64
# A20        int64
# A21       object
# A22       object
# A23       object
# A24       object
# A25       object
# A26       object
# A27       object
# A28       object
# A29       object
# A30       object
# Class    float64
# dtype: object

# %%
str_cols = ["A1", "A2", "A3", "A21", "A22", "A23", "A24", "A25", "A26", "A27", "A28", "A29", "A30"]
print(len(str_cols))
# Out:
# 13

# %%
# Label Encoding -- I've made a choice of encoding these column values like this. But it could be one-hot encoding
# depending upon what is the significance of these columns in the data and what they mean
# first converting the columns to pandas category type then encoding their values
for item in str_cols:
    my_df[item] = my_df[item].astype('category')
my_df.dtypes
# Out:
# A1       category
# A2       category
# A3       category
# A4          int64
# A5        float64
# A6          int64
# A7          int64
# A8        float64
# A9          int64
# A10       float64
# A16       float64
# A17         int64
# A18       float64
# A19         int64
# A20         int64
# A21      category
# A22      category
# A23      category
# A24      category
# A25      category
# A26      category
# A27      category
# A28      category
# A29      category
# A30      category
# Class     float64
# dtype: object

# %%
for item in str_cols:
    my_df[item] = my_df[item].cat.codes

# %%
# # checking string encoding of relevent columns
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     print(my_df)

# %% [markdown]
# # Test-Train

# %%
# Train Test Split
examples = my_df.copy()
examples = examples.drop(["Class"], axis=1)

# %%
ground_truth = my_df["Class"]
print(len(ground_truth))
print(ground_truth.head(3))
# Out:
# 879
# 0    1.0
# 1    1.0
# 2    1.0
# Name: Class, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(examples, ground_truth, test_size=0.3, random_state=42, shuffle=True)

# %% [markdown]
# # Logistic Regression

# %%
# Applying Logistic Regression for classificaiton
from sklearn.linear_model import LogisticRegression

# %%
# with default parameters
logisticRegr = LogisticRegression()

# %%
logisticRegr.fit(X_train, y_train)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
predictions = logisticRegr.predict(X_test)

# %%
score = logisticRegr.score(X_test, y_test)

# %%
print("Accurcy is: {}%".format(score*100))
# Out:
# Accurcy is: 71.96969696969697%

# %%
# Confusion Matrix

# %%
from sklearn import metrics
my_cm = metrics.confusion_matrix(y_test, predictions)
print(my_cm)
# Out:
# [[  3  67]
#  [  7 187]]

# %%
# Precison
# Recall
# F1 Score
print('clasification report:\n', sklearn.metrics.classification_report(y_test,predictions))
# Out:
# clasification report:
#                precision    recall  f1-score   support
#
#          0.0       0.30      0.04      0.07        70
#          1.0       0.74      0.96      0.83       194
#
#    micro avg       0.72      0.72      0.72       264
#    macro avg       0.52      0.50      0.45       264
# weighted avg       0.62      0.72      0.63       264
